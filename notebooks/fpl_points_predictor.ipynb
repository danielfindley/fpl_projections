# %% [markdown]
# # FPL Points Predictor
#
# Generates predictions for the upcoming gameweek automatically.

# %%
# ============================================================================
# STEP 1: UPDATE DATA - Get next GW fixtures and players
# ============================================================================
import sys
sys.path.insert(0, '..')

from scripts.update_data import main as update_data

# Run update to get next GW info
update_result = update_data()

CURRENT_GW = update_result['current_gw']
TARGET_GW = update_result['next_gw']
TARGET_SEASON = '2025-26'

print(f'\n🎯 Will generate predictions for GW{TARGET_GW}')
# Out:
# ======================================================================
# FPL DATA UPDATE SCRIPT
# ======================================================================
# Timestamp: 2025-12-17 19:32:28
# Checking FPL API for current gameweek...
#   Current GW: 16, Next GW: 17
#
# Current GW: 16 (latest completed)
# Next GW: 17 (to predict)
#
# [1] Fetching GW17 fixtures from FPL API...
#   Found 10 fixtures for GW17:
#     Newcastle vs Chelsea
#     Bournemouth vs Burnley
#     Brighton vs Sunderland
#     Man City vs West Ham
#     Wolves vs Brentford
#     Spurs vs Liverpool
#     Everton vs Arsenal
#     Leeds vs Crystal Palace
#     Aston Villa vs Man Utd
#     Fulham vs Nott'm Forest
#
#   Teams playing in GW17: 20
#
# [2] Finding players for 20 teams...
#   Found 295 unique players
#
# [3] Checking data status for GW16...
#   ✓ Found 10 matches, 20 team datasets
#
# [4] Creating prediction list for GW17...
#   ✓ Created 295 prediction rows
#     Teams: 15
#     Players: 295
#
# ✓ Saved fixtures to: C:\Users\dpfin\OneDrive\Desktop\ultimate_p_proj\data\upcoming\gw17_fixtures.csv
# ✓ Saved prediction list to: C:\Users\dpfin\OneDrive\Desktop\ultimate_p_proj\data\upcoming\gw17_players_to_predict.csv
#
# ======================================================================
# SUMMARY
# ======================================================================
#   Next gameweek: GW17
#   Fixtures: 10
#   Teams playing: 20
#   Players to predict: 295
#
#   Current GW16 data: ✓ Available
#
# ======================================================================
# NEXT STEPS
# ======================================================================
#   1. Ensure GW16 data is scraped and parsed
#   2. Run prediction pipeline for GW17:
#      from pipelines.fpl_prediction_pipeline import run_pipeline
#      predictions = run_pipeline(target_gw=17)
# ======================================================================
#
# 🎯 Will generate predictions for GW17

# %%
# ============================================================================
# STEP 2: RUN PREDICTION PIPELINE
# ============================================================================
from pipelines.fpl_prediction_pipeline import FPLPredictionPipeline

# Run the full pipeline
pipeline = FPLPredictionPipeline(data_dir='../data')
predictions = pipeline.run(target_gw=TARGET_GW, target_season=TARGET_SEASON, verbose=True)

# Store for analysis
test_df = predictions
print(f'\n✓ Generated {len(test_df)} predictions for GW{TARGET_GW}')
# Out:
# ================================================================================
# FPL PREDICTION PIPELINE - GW17 2025-26
# ================================================================================
# [1] Loading data from raw CSV files...
#   Loaded 49583 player-match records from 3354 team-matches
#   Seasons: ['2021-22', '2022-23', '2023-24', '2024-25', '2025-26']
# [2] Computing rolling features...
#   Computed 119 rolling features
# [3] Splitting train/test data...
#   Mode: Prediction (GW17 is upcoming)
#   Building prediction set for GW17...
#     Using historical data up to GW16
#     Found 10 fixtures, 20 teams
#     Found 468 players in prior GW data
#     Teams matched: 20/20
#     Final test set: 468 players with features
#   Train: 49583 records, Test: 468 records
# [4] Training minutes model...
# Training MinutesModel on 49583 samples (players who played 1+ min)...
#   Actual distribution:
#     Mean: 66.8, Median: 89.0
#     90 min: 25088 (50.6%)
#     60+ min: 34713 (70.0%)
#     <30 min: 10355 (20.9%)
#
#   Model predictions:
#     Mean: 77.1, Median: 82.7
#     MAE: 17.3
#     R²: 0.254
#     Predicted 90 min: 3262 (6.6%)
#     Predicted 60+ min: 42928 (86.6%)
# [5] Training goals model...
# 0        1.10
# 1        1.06
# 2        1.23
# 3        1.19
# 4        0.00
#          ...
# 49578    1.66
# 49579    1.41
# 49580    1.39
# 49581    1.42
# 49582    1.05
# Name: team_xg_roll10, Length: 49583, dtype: float64
# Training GoalsModel (per 90) on 49583 samples...
#   Mean goals/90: 0.124
#   Players with goals: 4307 (8.7%)
#   MAE: 0.2399
#   Predicted mean goals/90: 0.203
# [6] Training assists model...
# Training AssistsModel (per 90) on 49583 samples...
#   Mean assists/90: 0.088
#   Players with assists: 3195 (6.4%)
#   MAE: 0.1983
#   Predicted mean assists/90: 0.154
# [7] Training defcon model...
# Training DefconModel (per 90) on 49583 samples...
#   Mean defcon/90: 8.37
#   Players hitting threshold: 7672 (15.5%)
#   MAE: 3.89
#   Predicted mean defcon/90: 8.84
# [8] Training clean sheet model...
# Training CleanSheetModel on 3327 team-matches...
#   Clean sheet rate: 26.1%
#   Teams encoded: 27
#   ROC AUC: 0.959
#   Building CS predictions for upcoming fixtures...
#     Using 2025-26 data (GW1-16)
#     Teams in current season data: 20
#     DEBUG Arsenal DEF: conceded_last1=1.0, latest_gw=16.0
#     DEBUG Wolves DEF: conceded_last1=0.0, latest_gw=16.0
#     DEBUG Wolves ATK: goals_last1=1.0, latest_gw=16.0
#     DEBUG Arsenal ATK: goals_last1=0.0, latest_gw=16.0
#     Built 20 team fixtures for CS prediction
#     Arsenal CS features:
#       team_goals_conceded_last1: 1.0
#       opp_goals_scored_last1: 0.0
#       pred_cs_prob: 45.5%
# [8.5] Training bonus model...
# [Bonus] Fetching FPL bonus data...
#   Matched 596 players to FPL IDs
#     Fetched 100/596...
#     Fetched 200/596...
#     Fetched 300/596...
#     Fetched 400/596...
#     Fetched 500/596...
#   Fetched 9410 FPL gameweek records
# Training BonusModel on 3287 samples (players who played 60+ mins)...
#   Features used: 53
#   Avg bonus: 0.28
#   Players with bonus > 0: 462 (14.1%)
#   MAE: 0.225
#   R²: 0.753
#   Predicted avg: 0.28
# [9] Fetching FPL positions and calculating expected points...
# [FPL Positions] Fetching positions from FPL API...
#   Matched 453/465 players to FPL positions
#   Position distribution: {'MID': 210, 'DEF': 168, 'FWD': 60, 'GK': 30}
#
# ✓ Predictions saved to: ..\data\predictions\gw17_2025-26_predictions.csv
# ================================================================================
# PIPELINE COMPLETE!
# ================================================================================
# minutes FEATURE_IMPORTANCE:
#                     feature  importance
# 9             starter_score    0.439188
# 15              is_defender    0.096765
# 10             full_90_rate    0.072446
# 0         last_game_minutes    0.060761
# 14            is_goalkeeper    0.059364
# 4        roll10_minutes_avg    0.050292
# 1         roll3_minutes_avg    0.041429
# 17               is_forward    0.033202
# 16            is_midfielder    0.026963
# 19         team_goals_roll5    0.020801
# 5              roll5_starts    0.013840
# 3         roll5_minutes_sum    0.013750
# 11              goals_roll5    0.013083
# 13  goal_involvements_roll5    0.012646
# 18                  is_home    0.010332
# 2         roll5_minutes_avg    0.010281
# 12            assists_roll5    0.009852
# 7            last_was_start    0.009107
# 6            roll5_full_90s    0.005898
# 8          last_was_full_90    0.000000
# goals FEATURE_IMPORTANCE:
#                     feature  importance
# 19          xg_per90_roll10    0.109866
# 56               is_forward    0.073999
# 58              is_defender    0.045620
# 14       shots_per90_roll10    0.025290
# 24              goals_roll3    0.024354
# 25                 xg_roll3    0.021197
# 39        team_goals_roll20    0.020587
# 53    opp_xg_against_roll20    0.020505
# 57            is_midfielder    0.020389
# 52      opp_conceded_roll20    0.020017
# 51         opp_shots_roll10    0.019856
# 35           team_xg_roll10    0.019827
# 59            is_goalkeeper    0.019624
# 54         opp_shots_roll20    0.019505
# 21          sca_per90_roll5    0.019194
# 38           team_xg_roll20    0.019079
# 50    opp_xg_against_roll10    0.018922
# 20        shots_per90_roll5    0.018796
# 22          gca_per90_roll5    0.018508
# 42     opp_xg_against_roll5    0.018228
# 18           xg_per90_roll5    0.018066
# 17  key_passes_per90_roll10    0.017716
# 7           sca_per90_roll3    0.017417
# 15         sca_per90_roll10    0.017195
# 9           gca_per90_roll3    0.016983
# 41       opp_conceded_roll5    0.016848
# 40        team_shots_roll20    0.016754
# 34         team_shots_roll5    0.016651
# 13       goals_per90_roll10    0.016422
# 11   key_passes_per90_roll3    0.016157
# 10   key_passes_per90_roll1    0.015726
# 5         shots_per90_roll3    0.015465
# 16         gca_per90_roll10    0.015451
# 55                  is_home    0.015113
# 3            xg_per90_roll3    0.015084
# 32            team_xg_roll5    0.015017
# 8           gca_per90_roll1    0.014971
# 12        goals_per90_roll5    0.014878
# 33         team_goals_roll5    0.014776
# 49      opp_conceded_roll10    0.014745
# 4         shots_per90_roll1    0.014194
# 1         goals_per90_roll3    0.014105
# 36        team_goals_roll10    0.013871
# 0         goals_per90_roll1    0.013855
# 37        team_shots_roll10    0.013152
# 6           sca_per90_roll1    0.012775
# 2            xg_per90_roll1    0.011984
# 23              goals_last1    0.011266
# 44     opp_xg_against_roll1    0.000000
# 45          opp_shots_roll1    0.000000
# 46       opp_conceded_roll3    0.000000
# 47     opp_xg_against_roll3    0.000000
# 48          opp_shots_roll3    0.000000
# 43       opp_conceded_roll1    0.000000
# 31         team_shots_roll3    0.000000
# 29            team_xg_roll3    0.000000
# 28         team_shots_roll1    0.000000
# 27         team_goals_roll1    0.000000
# 26            team_xg_roll1    0.000000
# 30         team_goals_roll3    0.000000
# assists FEATURE_IMPORTANCE:
#                    feature  importance
# 15         sca_per90_roll5    0.070789
# 29             is_defender    0.063842
# 17  key_passes_per90_roll5    0.041427
# 14         xag_per90_roll5    0.040528
# 16         gca_per90_roll5    0.036212
# 4        shots_per90_roll1    0.036044
# 13    assists_per90_roll10    0.035342
# 22        team_goals_roll5    0.035170
# 27              is_forward    0.034614
# 20               xag_roll3    0.033400
# 6          sca_per90_roll1    0.032375
# 21           team_xg_roll5    0.032154
# 11  key_passes_per90_roll3    0.032080
# 0        goals_per90_roll1    0.031217
# 7          sca_per90_roll3    0.031116
# 1        goals_per90_roll3    0.030629
# 2           xg_per90_roll1    0.030111
# 24      opp_conceded_roll5    0.029970
# 25    opp_xg_against_roll5    0.029553
# 3           xg_per90_roll3    0.029039
# 23        team_shots_roll5    0.028249
# 10  key_passes_per90_roll1    0.028038
# 5        shots_per90_roll3    0.027908
# 12     assists_per90_roll5    0.025747
# 9          gca_per90_roll3    0.024942
# 26                 is_home    0.024541
# 8          gca_per90_roll1    0.024528
# 28           is_midfielder    0.024139
# 19           assists_roll3    0.023465
# 30           is_goalkeeper    0.016657
# 18           assists_last1    0.016175
# defcon FEATURE_IMPORTANCE:
#                       feature  importance
# 1         defcon_per90_roll10    0.299381
# 13              is_midfielder    0.288810
# 11       hit_threshold_roll10    0.065268
# 12                is_defender    0.053806
# 7      recoveries_per90_roll5    0.042098
# 5      clearances_per90_roll5    0.033935
# 0          defcon_per90_roll5    0.031195
# 10        hit_threshold_roll5    0.022504
# 14                    is_home    0.021699
# 2          defcon_per90_last1    0.020044
# 4   interceptions_per90_roll5    0.019651
# 9                defcon_roll3    0.019594
# 3         tackles_per90_roll5    0.019410
# 6          blocks_per90_roll5    0.016300
# 15               opp_xg_roll5    0.016151
# 16            opp_shots_roll5    0.016009
# 8                defcon_last1    0.014143
# clean_sheet FEATURE_IMPORTANCE:
#                        feature  importance
# 15     opp_goals_scored_roll30    0.068917
# 17           opp_xg_roll5_home    0.063169
# 21                     is_home    0.054811
# 10         team_xga_roll5_away    0.045571
# 4   team_goals_conceded_roll30    0.045001
# 8     team_clean_sheets_roll30    0.042224
# 2    team_goals_conceded_roll5    0.042154
# 9          team_xga_roll5_home    0.041636
# 20         defensive_advantage    0.041200
# 19                xga_xg_ratio    0.040760
# 22                team_encoded    0.039703
# 1    team_goals_conceded_roll3    0.038687
# 18           opp_xg_roll5_away    0.038242
# 11      opp_goals_scored_last1    0.037837
# 13      opp_goals_scored_roll5    0.037794
# 7     team_clean_sheets_roll10    0.037694
# 3   team_goals_conceded_roll10    0.037598
# 0    team_goals_conceded_last1    0.037537
# 12      opp_goals_scored_roll3    0.036696
# 5               team_xga_roll5    0.036630
# 6      team_clean_sheets_roll5    0.036080
# 14     opp_goals_scored_roll10    0.033895
# 16                opp_xg_roll5    0.033370
# 23            opponent_encoded    0.032793
# bonus FEATURE_IMPORTANCE:
#                       feature  importance
# 16         player_roll5_shots    0.041094
# 47             team_xg_roll10    0.027744
# 43           opp_shots_roll20    0.026273
# 52          team_shots_roll20    0.025946
# 51          team_goals_roll20    0.024301
# 17                goals_roll3    0.023182
# 40           opp_shots_roll10    0.023176
# 5           shots_per90_roll3    0.023092
# 9             gca_per90_roll3    0.022370
# 7             sca_per90_roll3    0.021203
# 48          team_goals_roll10    0.020650
# 38        opp_conceded_roll10    0.020520
# 12            player_roll5_xg    0.020300
# 28               defcon_last1    0.020216
# 26         blocks_per90_roll5    0.020169
# 29               defcon_roll3    0.019914
# 37       opp_xg_against_roll5    0.019847
# 23        tackles_per90_roll5    0.019797
# 21        defcon_per90_roll10    0.019743
# 42      opp_xg_against_roll20    0.019710
# 31                 is_forward    0.019662
# 15       player_roll5_assists    0.019410
# 45           team_goals_roll5    0.019407
# 30               defcon_roll5    0.019344
# 27     recoveries_per90_roll5    0.019184
# 44              team_xg_roll5    0.019128
# 46           team_shots_roll5    0.018965
# 4           shots_per90_roll1    0.018921
# 19    goal_involvements_roll5    0.018877
# 39      opp_xg_against_roll10    0.018871
# 49          team_shots_roll10    0.018840
# 10     key_passes_per90_roll1    0.018571
# 24  interceptions_per90_roll5    0.018374
# 20         defcon_per90_roll5    0.017998
# 50             team_xg_roll20    0.017944
# 14           player_roll5_xag    0.017711
# 11     key_passes_per90_roll3    0.017651
# 25     clearances_per90_roll5    0.017499
# 13         player_roll5_goals    0.016699
# 22         defcon_per90_last1    0.016502
# 41        opp_conceded_roll20    0.016359
# 8             gca_per90_roll1    0.016055
# 6             sca_per90_roll1    0.015928
# 36         opp_conceded_roll5    0.015754
# 2              xg_per90_roll1    0.015093
# 32              is_midfielder    0.014249
# 34              is_goalkeeper    0.014209
# 18              assists_roll3    0.012791
# 1           goals_per90_roll3    0.011939
# 3              xg_per90_roll3    0.011696
# 33                is_defender    0.009986
# 35                    is_home    0.009418
# 0           goals_per90_roll1    0.007721
#
# ✓ Generated 468 predictions for GW17

# %%
# STEP 3: VIEW TOP 40 PLAYERS
import pandas as pd

cols = ['player_name', 'team', 'position', 'opponent', 'pred_minutes',
        'pred_exp_goals', 'pred_exp_assists', 'pred_cs_prob', 
        'pred_defcon_prob', 'pred_bonus', 'exp_total_pts']

top40 = test_df.nlargest(40, 'exp_total_pts')[cols].copy()
top40['pred_minutes'] = top40['pred_minutes'].round(0).astype(int)
top40['pred_exp_goals'] = (top40['pred_exp_goals']*(top40["pred_minutes"]/90)).round(2)
top40['pred_exp_assists'] = (top40['pred_exp_assists']*(top40["pred_minutes"]/90)).round(2)
top40['pred_cs_prob'] = (top40['pred_cs_prob'] * 100).round(0).astype(str) + '%'
top40['pred_defcon_prob'] = (top40['pred_defcon_prob'] * 100).round(0).astype(str) + '%'
top40['pred_bonus'] = top40['pred_bonus'].round(2)
top40['exp_total_pts'] = top40['exp_total_pts'].round(2)

top40.columns = ['Player', 'Team', 'Pos', 'Opp', 'Mins', 'xG', 'xA', 'CS', 'DC', 'Bonus', 'Pts']
print(f'TOP 40 PLAYERS - GW{TARGET_GW}')
print('=' * 100)
top40
#print(top40.to_string(index=False))
# Out:
# TOP 40 PLAYERS - GW17
# ====================================================================================================
#                     Player                     Team       Pos             Opp  \
# 57         Bruno Fernandes        manchester_united        CM     Aston Villa
# 124         Erling Haaland          manchester_city        FW        West Ham
# 60             Bukayo Saka                  arsenal        RW         Everton
# 166           Hugo Ekitike                liverpool        FW           Spurs
# 304          Matheus Cunha        manchester_united     FW,AM     Aston Villa
# 373             Phil Foden          manchester_city        AM        West Ham
# 160           Harry Wilson                   fulham        RW   Nott'm Forest
# 333          Morgan Rogers              aston_villa        LW         Man Utd
# 328          Mohamed Salah                liverpool     RW,FW           Spurs
# 379           Raúl Jiménez                   fulham        FW   Nott'm Forest
# 103  Dominic Calvert-Lewin             leeds_united        FW  Crystal Palace
# 302       Mateus Fernandes          west_ham_united     LM,CM        Man City
# 96             Declan Rice                  arsenal     LM,CM         Everton
# 305          Matheus Nunes          manchester_city        RB        West Ham
# 392          Rodrigo Gomes  wolverhampton_wanderers  LW,RW,RM       Brentford
# 463        Youri Tielemans              aston_villa     AM,DM         Man Utd
# 161          Harvey Barnes         newcastle_united        LW         Chelsea
# 381       Reinildo Mandava               sunderland        LB        Brighton
# 146      Gabriel Magalhães                  arsenal        CB         Everton
# 324           Mikel Merino                  arsenal        LM         Everton
# 24          Anthony Gordon         newcastle_united        LW         Chelsea
# 201           Jarrod Bowen          west_ham_united     FW,RM        Man City
# 59            Bryan Mbeumo        manchester_united     AM,FW     Aston Villa
# 183           Jacob Murphy         newcastle_united        RW         Chelsea
# 210            Jeremy Doku          manchester_city     AM,LW        West Ham
# 268             Lewis Hall         newcastle_united        LB         Chelsea
# 255  Kiernan Dewsbury-Hall                  everton        AM         Arsenal
# 90            Daniel Muñoz           crystal_palace     WB,RM           Leeds
# 76              Cody Gakpo                liverpool        LW           Spurs
# 42               Ben White                  arsenal        RB         Everton
# 423                 Thiago                brentford        FW          Wolves
# 170        Ibrahima Konaté                liverpool        CB           Spurs
# 449          Wesley Fofana                  chelsea        CB       Newcastle
# 445        Virgil van Dijk                liverpool        CB           Spurs
# 261        Ladislav Krejčí  wolverhampton_wanderers        CM       Brentford
# 241         Jurriën Timber                  arsenal     RB,CB         Everton
# 345          Nico O’Reilly          manchester_city        LB        West Ham
# 251           Kevin Schade                brentford        LW          Wolves
# 148       Georginio Rutter    brighton__hove_albion        FW      Sunderland
# 286             Malo Gusto                  chelsea        RB       Newcastle
#
#      Mins    xG    xA     CS     DC  Bonus    Pts
# 57     89  0.53  0.57  13.0%  48.0%   2.89  10.37
# 124    88  1.12  0.26  38.0%   0.0%   2.89  10.29
# 60     82  0.39  0.48  46.0%  22.0%   2.84   9.45
# 166    76  0.76  0.15  36.0%   1.0%   2.53   8.69
# 304    88  0.44  0.29  13.0%  23.0%   1.96   8.52
# 373    88  0.81  0.22  38.0%  10.0%   1.05   8.46
# 160    81  0.44  0.32  30.0%   1.0%   1.75   7.56
# 333    89  0.46  0.31  36.0%   2.0%   1.77   7.44
# 328    88  0.29  0.84  36.0%   0.0%   0.88   7.29
# 379    83  0.48  0.21  30.0%   1.0%   0.20   7.22
# 103    84  0.52  0.20  31.0%   0.0%   2.26   7.14
# 302    88  0.14  0.15   7.0%  80.0%   1.88   7.06
# 96     88  0.26  0.44  46.0%  66.0%   0.31   6.77
# 305    89  0.08  0.20  38.0%  38.0%   1.37   6.73
# 392    74  0.36  0.09  35.0%   2.0%   0.19   6.57
# 463    80  0.27  0.40  36.0%  38.0%   0.57   6.56
# 161    70  0.49  0.14  36.0%   0.0%   0.49   6.52
# 381    88  0.04  0.05  27.0%  44.0%   2.12   6.47
# 146    89  0.13  0.08  46.0%  65.0%   0.29   6.42
# 324    88  0.45  0.16  46.0%  31.0%   0.40   6.29
# 24     74  0.44  0.17  36.0%   0.0%   0.48   6.18
# 201    89  0.41  0.20   7.0%  13.0%   1.64   6.15
# 59     89  0.50  0.24  13.0%  13.0%   0.48   6.11
# 183    80  0.31  0.23  36.0%   0.0%   1.17   6.05
# 210    80  0.38  0.39  38.0%   3.0%   0.16   6.03
# 268    81  0.17  0.23  36.0%  30.0%   0.03   5.99
# 255    88  0.28  0.24  32.0%  60.0%   0.22   5.93
# 90     89  0.25  0.08  14.0%  19.0%   1.16   5.89
# 76     80  0.45  0.22  36.0%   2.0%   0.22   5.87
# 42     88  0.09  0.21  46.0%  27.0%   0.29   5.87
# 423    86  0.66  0.19  29.0%  10.0%   0.28   5.85
# 170    88  0.06  0.06  36.0%  55.0%   0.73   5.79
# 449    88  0.08  0.05  23.0%  45.0%   1.26   5.76
# 445    89  0.07  0.08  36.0%  68.0%   0.24   5.73
# 261    88  0.22  0.08  35.0%  37.0%   0.00   5.73
# 241    88  0.12  0.11  46.0%  24.0%   0.31   5.70
# 345    88  0.15  0.12  38.0%  41.0%   0.03   5.68
# 251    88  0.52  0.14  29.0%  11.0%   0.10   5.68
# 148    82  0.48  0.24  10.0%   2.0%   0.10   5.68
# 286    84  0.11  0.11  23.0%  12.0%   1.44   5.67

# %%
test_df.loc[test_df['player_name']=="Erling Haaland"][['player_name', 'team', 'position', 'opponent', 'pred_minutes',
        'pred_exp_goals', 'pred_exp_assists', 'pred_cs_prob', 
        'pred_defcon_prob', 'pred_bonus', 'exp_total_pts']]
# Out:
#         player_name             team position  opponent  pred_minutes  \
# 124  Erling Haaland  manchester_city       FW  West Ham          88.0
#
#      pred_exp_goals  pred_exp_assists  pred_cs_prob  pred_defcon_prob  \
# 124        1.146193          0.269792      0.382814          0.003748
#
#      pred_bonus  exp_total_pts
# 124    2.885884      10.287527

# %%
test_df.loc[test_df['player_name'].str.contains("nzo")][['player_name', 'team', 'position', 'opponent', 'pred_minutes',
        'pred_exp_goals', 'pred_exp_assists', 'pred_cs_prob', 
        'pred_defcon_prob', 'pred_bonus', 'exp_total_pts']]
# Out:
#         player_name        team position   opponent  pred_minutes  \
# 122  Enzo Fernández     chelsea    DM,AM  Newcastle          88.0
# 123     Enzo Le Fée  sunderland       AM   Brighton          88.0
#
#      pred_exp_goals  pred_exp_assists  pred_cs_prob  pred_defcon_prob  \
# 122        0.380463          0.185628      0.234034          0.166711
# 123        0.200662          0.088197      0.272104          0.225092
#
#      pred_bonus  exp_total_pts
# 122    0.082674       5.109328
# 123    0.040920       4.031111

# %%
test_df.loc[test_df['player_name']=="Harry Wilson"][['player_name', 'team', 'position', 'opponent', 'pred_minutes',
        'pred_exp_goals', 'pred_exp_assists', 'pred_cs_prob', 
        'pred_defcon_prob', 'pred_bonus', 'exp_total_pts']]
# Out:
#       player_name    team position       opponent  pred_minutes  \
# 160  Harry Wilson  fulham       RW  Nott'm Forest      81.29879
#
#      pred_exp_goals  pred_exp_assists  pred_cs_prob  pred_defcon_prob  \
# 160         0.48404          0.353103      0.302973          0.013914
#
#      pred_bonus  exp_total_pts
# 160     1.75015       7.560459

# %%
# STEP 4: DETAILED TOP 10
print(f'DETAILED PREDICTIONS - TOP 10 FOR GW{TARGET_GW}')
print('=' * 100)

for i, (_, row) in enumerate(test_df.nlargest(10, 'exp_total_pts').iterrows()):
    home_away = 'H' if row.get('is_home', 0) == 1 else 'A'
    print(f'\n{i+1}. {row["player_name"]} ({row["team"]}) {home_away} vs {row["opponent"]}')
    print(f'   Position: {row["position"]} | Predicted Minutes: {row["pred_minutes"]:.0f}')
    print(f'   Goals:   xG={row["pred_exp_goals"]:.2f} -> {row["exp_goals_pts"]:.2f} pts')
    print(f'   Assists: xA={row["pred_exp_assists"]:.2f} -> {row["exp_assists_pts"]:.2f} pts')
    print(f'   CS: {row["pred_cs_prob"]*100:.0f}% -> {row["exp_cs_pts"]:.2f} pts')
    print(f'   Defcon: {row["pred_defcon_prob"]*100:.0f}% -> {row["exp_defcon_pts"]:.2f} pts')
    print(f'   Bonus: {row.get("pred_bonus", 0):.2f} pts')
    print(f'   Appearance: {row["exp_appearance_pts"]:.0f} pts')
    print(f'   TOTAL: {row["exp_total_pts"]:.2f} pts')
# Out:
# DETAILED PREDICTIONS - TOP 10 FOR GW17
# ====================================================================================================
#
# 1. Bruno Fernandes (manchester_united) A vs Aston Villa
#    Position: CM | Predicted Minutes: 89
#    Goals:   xG=0.53 -> 2.66 pts
#    Assists: xA=0.57 -> 1.72 pts
#    CS: 13% -> 0.13 pts
#    Defcon: 48% -> 0.97 pts
#    Bonus: 2.89 pts
#    Appearance: 2 pts
#    TOTAL: 10.37 pts
#
# 2. Erling Haaland (manchester_city) H vs West Ham
#    Position: FW | Predicted Minutes: 88
#    Goals:   xG=1.15 -> 4.58 pts
#    Assists: xA=0.27 -> 0.81 pts
#    CS: 38% -> 0.00 pts
#    Defcon: 0% -> 0.01 pts
#    Bonus: 2.89 pts
#    Appearance: 2 pts
#    TOTAL: 10.29 pts
#
# 3. Bukayo Saka (arsenal) A vs Everton
#    Position: RW | Predicted Minutes: 82
#    Goals:   xG=0.42 -> 2.12 pts
#    Assists: xA=0.53 -> 1.59 pts
#    CS: 46% -> 0.46 pts
#    Defcon: 22% -> 0.45 pts
#    Bonus: 2.84 pts
#    Appearance: 2 pts
#    TOTAL: 9.45 pts
#
# 4. Hugo Ekitike (liverpool) A vs Spurs
#    Position: FW | Predicted Minutes: 76
#    Goals:   xG=0.90 -> 3.62 pts
#    Assists: xA=0.17 -> 0.52 pts
#    CS: 36% -> 0.00 pts
#    Defcon: 1% -> 0.02 pts
#    Bonus: 2.53 pts
#    Appearance: 2 pts
#    TOTAL: 8.69 pts
#
# 5. Matheus Cunha (manchester_united) A vs Aston Villa
#    Position: FW,AM | Predicted Minutes: 88
#    Goals:   xG=0.45 -> 2.70 pts
#    Assists: xA=0.30 -> 0.90 pts
#    CS: 13% -> 0.52 pts
#    Defcon: 23% -> 0.45 pts
#    Bonus: 1.96 pts
#    Appearance: 2 pts
#    TOTAL: 8.52 pts
#
# 6. Phil Foden (manchester_city) H vs West Ham
#    Position: AM | Predicted Minutes: 88
#    Goals:   xG=0.83 -> 4.16 pts
#    Assists: xA=0.22 -> 0.66 pts
#    CS: 38% -> 0.38 pts
#    Defcon: 10% -> 0.20 pts
#    Bonus: 1.05 pts
#    Appearance: 2 pts
#    TOTAL: 8.46 pts
#
# 7. Harry Wilson (fulham) H vs Nott'm Forest
#    Position: RW | Predicted Minutes: 81
#    Goals:   xG=0.48 -> 2.42 pts
#    Assists: xA=0.35 -> 1.06 pts
#    CS: 30% -> 0.30 pts
#    Defcon: 1% -> 0.03 pts
#    Bonus: 1.75 pts
#    Appearance: 2 pts
#    TOTAL: 7.56 pts
#
# 8. Morgan Rogers (aston_villa) H vs Man Utd
#    Position: LW | Predicted Minutes: 89
#    Goals:   xG=0.46 -> 2.31 pts
#    Assists: xA=0.32 -> 0.95 pts
#    CS: 36% -> 0.36 pts
#    Defcon: 2% -> 0.05 pts
#    Bonus: 1.77 pts
#    Appearance: 2 pts
#    TOTAL: 7.44 pts
#
# 9. Mohamed Salah (liverpool) A vs Spurs
#    Position: RW,FW | Predicted Minutes: 88
#    Goals:   xG=0.30 -> 1.48 pts
#    Assists: xA=0.86 -> 2.57 pts
#    CS: 36% -> 0.36 pts
#    Defcon: 0% -> 0.01 pts
#    Bonus: 0.88 pts
#    Appearance: 2 pts
#    TOTAL: 7.29 pts
#
# 10. Raúl Jiménez (fulham) H vs Nott'm Forest
#    Position: FW | Predicted Minutes: 83
#    Goals:   xG=0.52 -> 3.12 pts
#    Assists: xA=0.23 -> 0.68 pts
#    CS: 30% -> 1.21 pts
#    Defcon: 1% -> 0.01 pts
#    Bonus: 0.20 pts
#    Appearance: 2 pts
#    TOTAL: 7.22 pts

# %%
# STEP 5: BREAKDOWN BY POSITION
print(f'\nTOP PLAYERS BY POSITION - GW{TARGET_GW}')
print('=' * 80)

def get_fpl_pos(pos):
    if pd.isna(pos): return 'MID'
    pos = str(pos).upper()
    if 'GK' in pos: return 'GK'
    elif any(p in pos for p in ['CB', 'LB', 'RB', 'WB', 'DF']): return 'DEF'
    elif any(p in pos for p in ['FW', 'CF', 'ST', 'LW', 'RW']): return 'FWD'
    return 'MID'

test_df['fpl_pos'] = test_df['position'].apply(get_fpl_pos)

for pos in ['GK', 'DEF', 'MID', 'FWD']:
    print(f'\n--- {pos} ---')
    pos_df = test_df[test_df['fpl_pos'] == pos].nlargest(5, 'exp_total_pts')
    for _, row in pos_df.iterrows():
        print(f"  {row['player_name']:20s} ({row['team']:15s}) vs {row['opponent']:15s} -> {row['exp_total_pts']:.2f} pts")
# Out:
# TOP PLAYERS BY POSITION - GW17
# ================================================================================
#
# --- GK ---
#   Robin Roefs          (sunderland     ) vs Brighton        -> 5.09 pts
#   David Raya           (arsenal        ) vs Everton         -> 3.87 pts
#   Nick Pope            (newcastle_united) vs Chelsea         -> 3.82 pts
#   James Trafford       (manchester_city) vs West Ham        -> 3.78 pts
#   Marco Bizot          (aston_villa    ) vs Man Utd         -> 3.77 pts
#
# --- DEF ---
#   Matheus Nunes        (manchester_city) vs West Ham        -> 6.73 pts
#   Reinildo Mandava     (sunderland     ) vs Brighton        -> 6.47 pts
#   Gabriel Magalhães    (arsenal        ) vs Everton         -> 6.42 pts
#   Lewis Hall           (newcastle_united) vs Chelsea         -> 5.99 pts
#   Daniel Muñoz         (crystal_palace ) vs Leeds           -> 5.89 pts
#
# --- MID ---
#   Bruno Fernandes      (manchester_united) vs Aston Villa     -> 10.37 pts
#   Phil Foden           (manchester_city) vs West Ham        -> 8.46 pts
#   Mateus Fernandes     (west_ham_united) vs Man City        -> 7.06 pts
#   Declan Rice          (arsenal        ) vs Everton         -> 6.77 pts
#   Youri Tielemans      (aston_villa    ) vs Man Utd         -> 6.56 pts
#
# --- FWD ---
#   Erling Haaland       (manchester_city) vs West Ham        -> 10.29 pts
#   Bukayo Saka          (arsenal        ) vs Everton         -> 9.45 pts
#   Hugo Ekitike         (liverpool      ) vs Spurs           -> 8.69 pts
#   Matheus Cunha        (manchester_united) vs Aston Villa     -> 8.52 pts
#   Harry Wilson         (fulham         ) vs Nott'm Forest   -> 7.56 pts

# %%
# STEP 6: SAVE PREDICTIONS
from pathlib import Path

output_dir = Path('../data/predictions')
output_dir.mkdir(exist_ok=True)

output_path = output_dir / f'gw{TARGET_GW}_{TARGET_SEASON}_predictions.csv'
test_df.to_csv(output_path, index=False)

print(f'Saved predictions to: {output_path}')
print(f'Total players: {len(test_df)}')
# Out:
# Saved predictions to: ..\data\predictions\gw17_2025-26_predictions.csv
# Total players: 468

# %%
# Show Arsenal's CS prediction input features for GW16
from models.clean_sheet_model import CleanSheetModel

features = CleanSheetModel.FEATURES

# Find Arsenal in test_df
arsenal = test_df[test_df['team'].str.contains('manchester_united', case=False, na=False)].iloc[0]

print(f"fulham vs {arsenal['opponent']} - CS Prob: {arsenal['pred_cs_prob']:.1%}")
print(f"\n{'='*60}")
print("CS MODEL INPUT FEATURES:")
print(f"{'='*60}")

for feat in features:
    if feat in arsenal.index:
        val = arsenal[feat]
        print(f"  {feat}: {val}")
    else:
        print(f"  {feat}: NOT IN DATA")
# Out:
# fulham vs Aston Villa - CS Prob: 13.0%
#
# ============================================================
# CS MODEL INPUT FEATURES:
# ============================================================
#   team_goals_conceded_last1: 4.0
#   team_goals_conceded_roll3: 2.0
#   team_goals_conceded_roll5: 1.6
#   team_goals_conceded_roll10: 1.4
#   team_goals_conceded_roll30: 1.4333333333333333
#   team_xga_roll5: 0.8400000000000001
#   team_clean_sheets_roll5: 0.0
#   team_clean_sheets_roll10: 1.0
#   team_clean_sheets_roll30: 4.0
#   team_xga_roll5_home: 0.5599999999999999
#   team_xga_roll5_away: 0.8400000000000001
#   opp_goals_scored_last1: 2.0
#   opp_goals_scored_roll3: 2.6666666666666665
#   opp_goals_scored_roll5: 2.2
#   opp_goals_scored_roll10: 2.2
#   opp_goals_scored_roll30: 2.2
#   opp_xg_roll5: NOT IN DATA
#   opp_xg_roll5_home: 1.56
#   opp_xg_roll5_away: 1.44
#   xga_xg_ratio: 0.5060240963855421
#   defensive_advantage: 0.72
#   is_home: 0
#   team_encoded: 16
#   opponent_encoded: 1

# %%
# Show Arsenal's CS prediction input features for GW16
from models.clean_sheet_model import CleanSheetModel

features = CleanSheetModel.FEATURES

# Find Arsenal in test_df
arsenal = test_df[test_df['team'].str.contains('arsenal', case=False, na=False)].iloc[0]

print(f"Arsenal vs {arsenal['opponent']} - CS Prob: {arsenal['pred_cs_prob']:.1%}")
print(f"\n{'='*60}")
print("CS MODEL INPUT FEATURES:")
print(f"{'='*60}")

for feat in features:
    if feat in arsenal.index:
        val = arsenal[feat]
        print(f"  {feat}: {val}")
    else:
        print(f"  {feat}: NOT IN DATA")
# Out:
# Arsenal vs Everton - CS Prob: 45.5%
#
# ============================================================
# CS MODEL INPUT FEATURES:
# ============================================================
#   team_goals_conceded_last1: 1.0
#   team_goals_conceded_roll3: 1.0
#   team_goals_conceded_roll5: 1.0
#   team_goals_conceded_roll10: 0.7
#   team_goals_conceded_roll30: 0.7333333333333333
#   team_xga_roll5: 0.72
#   team_clean_sheets_roll5: 1.0
#   team_clean_sheets_roll10: 5.0
#   team_clean_sheets_roll30: 13.0
#   team_xga_roll5_home: 0.42000000000000004
#   team_xga_roll5_away: 0.72
#   opp_goals_scored_last1: 0.0
#   opp_goals_scored_roll3: 1.0
#   opp_goals_scored_roll5: 1.0
#   opp_goals_scored_roll10: 1.0
#   opp_goals_scored_roll30: 1.0
#   opp_xg_roll5: NOT IN DATA
#   opp_xg_roll5_home: 0.9600000000000002
#   opp_xg_roll5_away: 1.3
#   xga_xg_ratio: 0.6792452830188678
#   defensive_advantage: 0.2400000000000002
#   is_home: 0
#   team_encoded: 0
#   opponent_encoded: 8

# %% [markdown]
# # FPL Points Predictor
#
# Uses predicted probabilities to calculate expected FPL points:
# - P(Goal) × Goal Points (by position)
# - P(Assist) × 3
# - P(Clean Sheet) × CS Points (by position)
# - P(Defcon) × 2 (hitting defensive action threshold)
# - Predicted Bonus Points (from BonusModel)
# - Expected Minutes → Appearance Points
#
# ## FPL Scoring Rules
# | Action | GK | DEF | MID | FWD |
# |--------|----|----|-----|-----|
# | Goal | 6 | 6 | 5 | 4 |
# | Assist | 3 | 3 | 3 | 3 |
# | Clean Sheet | 4 | 4 | 1 | 0 |
# | Defcon (10+ DEF / 12+ MID,FWD) | 0 | 2 | 2 | 2 |
# | 60+ mins | 2 | 2 | 2 | 2 |
# | 1-59 mins | 1 | 1 | 1 | 1 |
# | Bonus | 1-3 | 1-3 | 1-3 | 1-3 |
